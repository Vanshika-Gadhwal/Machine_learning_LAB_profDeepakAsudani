# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
x = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y = np.array([20, 40, 50, 65, 85])

# %%
x = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y = np.array([20, 40, 50, 65, 85])

# %%
X_manual = np.column_stack((np.ones(len(x)), x, x**2))

# %%
beta = np.linalg.inv(X_manual.T @ X_manual) @ (X_manual.T @ y)

# %%
print("Coefficients (B0, B1, B2):", beta)
# Out:
# Coefficients (B0, B1, B2): [ 8.         13.35714286  0.35714286]

# %%
y_pred_manual = X_manual @ beta

# %%
mae = mean_absolute_error(y, y_pred_manual)
mse = mean_squared_error(y, y_pred_manual)
rmse = np.sqrt(mse)
r2_manual = r2_score(y, y_pred_manual)

# %%
print(mae)
print(mse)
print(rmse)
print(r2_manual)
# Out:
# 2.0571428571429022
# 5.142857142857141
# 2.267786838055363
# 0.9894179894179894
